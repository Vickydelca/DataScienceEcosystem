# %% [markdown]
# ![image.png](attachment:cb14575a-d40c-4cab-ae0b-485d7d338912.png)![image.png](attachment:f0ab09ce-c6af-4ae2-b511-165ea1e72256.png)![image.png](attachment:6c77cb9e-e0f8-4054-8094-61c61bd70bda.png)![image.png](attachment:43ddfed4-a0d3-4242-8821-39ad3a6af965.png)Data Science Tools
# Jupyter Notebooks
# Pytorch
# ML Flow

# %% [markdown]
# ![image.png](attachment:2bcc82eb-cb5c-4328-b86d-8ab046aa0a4e.png)![image.png](attachment:303a11ce-e50a-43b8-b17b-f7bce6dc4d9d.png)![image.png](attachment:dc0c31fd-0d70-4def-95fe-136ad07c852f.png)![image.png](attachment:554bceec-6f0f-48c8-97a0-7eb826e563ef.png)Data Science Tools
#
# Jupyter Notebooks
# Pytorch
# ML
# Flow

# %% [markdown]
# ### Below are a few examples of evaluating arithmetic expressions in Python

# %% [markdown]
# This is a simple arithmetic expression to multiply then add integers

# %%
(3*4)+5
# Out:
# 17

# %% [markdown]
# This will convert 200 minutes to hours by diving by 60

# %%
(200/60)
# Out:
# 3.3333333333333335

# %% [markdown]
# In this Notebook, Data Science Tools are summarized

# %% [markdown]
# **Objectives:**

# %% [markdown]
# - List popular languages for Data Science
# - Using markdowns in Jupyter Notebooks
# - Working with files in Jupyter Notebooks

# %% [markdown]
# ## <Lakshmi Holla
# Virginia del Campo
